# %% [markdown]
# ## 1. The oldest businesses in the world
# <p>This is Staffelter Hof Winery, Germany's oldest business, which was established in 862 under the Carolingian dynasty. It has continued to serve customers through dramatic changes in Europe such as the Holy Roman Empire, the Ottoman Empire, and both world wars. What characteristics enable a business to stand the test of time? Image credit: <a href="https://commons.wikimedia.org/wiki/File:MKn_Staffelter_Hof.jpg">Martin Kraft</a>
# <img src="https://assets.datacamp.com/production/project_1383/./img/MKn_Staffelter_Hof.jpeg" alt="The entrance to Staffelter Hof Winery, a German winery established in 862." width="400"></p>
# <p>To help answer this question, BusinessFinancing.co.uk <a href="https://businessfinancing.co.uk/the-oldest-company-in-almost-every-country">researched</a> the oldest company that is still in business in almost every country and compiled the results into a dataset. Let's explore this work to to better understand these historic businesses. Our datasets, which are all located in the <code>datasets</code> directory, contain the following information: </p>
# <h3 id="businessesandnew_businesses"><code>businesses</code> and <code>new_businesses</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>business</code></td>
# <td>varchar</td>
# <td>Name of the business.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>year_founded</code></td>
# <td>int</td>
# <td>Year the business was founded.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>category_code</code></td>
# <td>varchar</td>
# <td>Code for the category of the business.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>country_code</code></td>
# <td>char</td>
# <td>ISO 3166-1 3-letter country code.</td>
# </tr>
# </tbody>
# </table>
# <h3 id="countries"><code>countries</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>country_code</code></td>
# <td>varchar</td>
# <td>ISO 3166-1 3-letter country code.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>country</code></td>
# <td>varchar</td>
# <td>Name of the country.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>continent</code></td>
# <td>varchar</td>
# <td>Name of the continent that the country exists in.</td>
# </tr>
# </tbody>
# </table>
# <h3 id="categories"><code>categories</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>category_code</code></td>
# <td>varchar</td>
# <td>Code for the category of the business.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>category</code></td>
# <td>varchar</td>
# <td>Description of the business category.</td>
# </tr>
# </tbody>
# </table>
# <p>Now let's learn about some of the world's oldest businesses still in operation!</p>

# %%
# Import the pandas library under its usual alias
import pandas as pd

# Load the business.csv file as a DataFrame called businesses
businesses = pd.read_csv("datasets/businesses.csv")

# Sort businesses from oldest businesses to youngest
sorted_businesses = businesses.sort_values("year_founded")

# Display the first few lines of sorted_businesses

print(sorted_businesses.shape[0])
sorted_businesses.head()
# Out:
# 163
#                         business  year_founded category_code country_code
# 64                    Kongō Gumi           578          CAT6          JPN
# 94   St. Peter Stifts Kulinarium           803          CAT4          AUT
# 107        Staffelter Hof Winery           862          CAT9          DEU
# 106            Monnaie de Paris            864         CAT12          FRA
# 103               The Royal Mint           886         CAT12          GBR

# %% [markdown]
# ## 2. The oldest businesses in North America
# <p>So far we've learned that Kongō Gumi is the world's oldest continuously operating business, beating out the second oldest business by well over 100 years! It's a little hard to read the country codes, though. Wouldn't it be nice if we had a list of country names to go along with the country codes?</p>
# <p>Enter <code>countries.csv</code>, which is also located in the <code>datasets</code> folder. Having useful information in different files is a common problem: for data storage, it's better to keep different types of data separate, but for analysis, we want all the data in one place. To solve this, we'll have to join the two tables together. </p>
# <h3 id="countries"><code>countries</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>country_code</code></td>
# <td>varchar</td>
# <td>ISO 3166-1 3-letter country code.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>country</code></td>
# <td>varchar</td>
# <td>Name of the country.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>continent</code></td>
# <td>varchar</td>
# <td>Name of the continent that the country exists in.</td>
# </tr>
# </tbody>
# </table>
# <p>Since <code>countries.csv</code> contains a <code>continent</code> column, merging the datasets will also allow us to look at the oldest business on each continent! </p>

# %%
# Load countries.csv to a DataFrame
countries = pd.read_csv("datasets/countries.csv")

# Merge sorted_businesses with countries
businesses_countries = sorted_businesses.merge(countries , on='country_code')
businesses_countries
# Out:
#                                            business  year_founded  \
# 0                                        Kongō Gumi           578
# 1                       St. Peter Stifts Kulinarium           803
# 2                             Staffelter Hof Winery           862
# 3                                 Monnaie de Paris            864
# 4                                    The Royal Mint           886
# 5                                        Sean's Bar           900
# 6                            Marinelli Bell Foundry          1040
# 7                                  Affligem Brewery          1074
# 8                                       Munke Mølle          1135
# 9                Ma Yu Ching's Bucket Chicken House          1153
# 10                                Casa de Ganaderos          1218
# 11                                  Gasthof Sternen          1230
# 12                                Bochnia Salt Mine          1248
# 13                             Drohobych salt plant          1250
# 14                                    Kremnica Mint          1328
# 15                                The Brand Brewery          1340
# 16                                  Skyllbergs bruk          1346
# 17                                  Pivovar Broumov          1348
# 18                                        Raeapteek          1422
# 19                                  Gostilna Gastuž          1467
# 20                                           Mousel          1511
# 21                      CTT-Correios de Portugal SA          1520
# 22                      La Casa de Moneda de México          1534
# 23                          Casa Nacional de Moneda          1565
# 24                               Çemberlitaş Hamamı          1584
# 25                                        Cēsu Alus          1590
# 26                                     Piraeus Bank          1606
# 27                       Casa de Moneda de Colombia          1621
# 28                               Shirley Plantation          1638
# 29                                     Posten Norge          1647
# ..                                              ...           ...
# 133                Cameroon Development Corporation          1947
# 134                       Myanmar National Airlines          1948
# 135          Salam International Investment Limited          1952
# 136                       National Bank of Cambodia          1954
# 137                                         Brarudi          1955
# 138     Office de Radiodiffusion-Télévision du Mali          1957
# 139                                     Tashi Group          1959
# 140                             Electricite du Laos          1959
# 141         Office of Radio and Television of Niger          1960
# 142                                    Halco Mining          1962
# 143                                 Yemenia Airways          1962
# 144                                  Air Madagascar          1962
# 145                                      Swazi Rail          1963
# 146                 Malawi Broadcasting Corporation          1964
# 147                        Botswana Meat Commission          1965
# 148                                     Air Burkina          1967
# 149                  Communauté Électrique du Bénin          1968
# 150                                  BGFIBank Group          1971
# 151                                      Cotontchad          1971
# 152                      Central Bank of Mauritania          1973
# 153                        Correios da Guiné-Bissau          1973
# 154           Central Bank of São Tomé and Príncipe          1975
# 155  Development Bank of the Central African States          1975
# 156                                  Air Seychelles          1977
# 157                         Central Bank of Lesotho          1978
# 158                     Central Bank of the Comoros          1981
# 159                          European Trust Company          1991
# 160                                      Ivory Bank          1994
# 161                      Guinea Ecuatorial Airlines          1996
# 162                            Meridian Corporation          1999
#
#     category_code country_code                           country  \
# 0            CAT6          JPN                             Japan
# 1            CAT4          AUT                           Austria
# 2            CAT9          DEU                           Germany
# 3           CAT12          FRA                            France
# 4           CAT12          GBR                    United Kingdom
# 5            CAT4          IRL                           Ireland
# 6           CAT12          ITA                             Italy
# 7            CAT9          BEL                           Belgium
# 8           CAT12          DNK                           Denmark
# 9            CAT4          CHN                             China
# 10           CAT1          ESP                             Spain
# 11          CAT19          CHE                       Switzerland
# 12          CAT15          POL                            Poland
# 13          CAT12          UKR                           Ukraine
# 14          CAT12          SVK                          Slovakia
# 15           CAT9          NLD                       Netherlands
# 16          CAT12          SWE                            Sweden
# 17           CAT9          CZE                           Czechia
# 18          CAT14          EST                           Estonia
# 19          CAT19          SVN                          Slovenia
# 20           CAT9          LUX                        Luxembourg
# 21          CAT16          PRT                          Portugal
# 22          CAT12          MEX                            Mexico
# 23           CAT3          PER                              Peru
# 24          CAT19          TUR                            Turkey
# 25           CAT9          LVA                            Latvia
# 26           CAT3          GRC                            Greece
# 27          CAT12          COL                          Colombia
# 28           CAT1          USA                     United States
# 29          CAT16          NOR                            Norway
# ..            ...          ...                               ...
# 133          CAT1          CMR                          Cameroon
# 134          CAT2          MMR                           Myanmar
# 135          CAT5          QAT                             Qatar
# 136          CAT3          KHM                          Cambodia
# 137          CAT9          BDI                           Burundi
# 138         CAT13          MLI                              Mali
# 139          CAT2          BTN                            Bhutan
# 140         CAT10          LAO  Lao People's Democratic Republic
# 141         CAT13          NER                             Niger
# 142         CAT15          GIN                            Guinea
# 143          CAT2          YEM                             Yemen
# 144          CAT2          MDG                        Madagascar
# 145          CAT2          SWZ                          Eswatini
# 146         CAT13          MWI                            Malawi
# 147          CAT1          BWA                          Botswana
# 148          CAT2          BFA                      Burkina Faso
# 149         CAT10          BEN                             Benin
# 150          CAT3          GAB                             Gabon
# 151          CAT1          TCD                              Chad
# 152          CAT3          MRT                        Mauritania
# 153         CAT16          GNB                     Guinea-Bissau
# 154          CAT3          STP             Sao Tome and Principe
# 155          CAT3          COG                             Congo
# 156          CAT2          SYC                        Seychelles
# 157          CAT3          LSO                           Lesotho
# 158          CAT3          COM                           Comoros
# 159          CAT3          VUT                           Vanuatu
# 160          CAT3          SSD                       South Sudan
# 161          CAT2          GNQ                 Equatorial Guinea
# 162         CAT13           XK                            Kosovo
#
#          continent
# 0             Asia
# 1           Europe
# 2           Europe
# 3           Europe
# 4           Europe
# 5           Europe
# 6           Europe
# 7           Europe
# 8           Europe
# 9             Asia
# 10          Europe
# 11          Europe
# 12          Europe
# 13          Europe
# 14          Europe
# 15          Europe
# 16          Europe
# 17          Europe
# 18          Europe
# 19          Europe
# 20          Europe
# 21          Europe
# 22   North America
# 23   South America
# 24            Asia
# 25          Europe
# 26          Europe
# 27   South America
# 28   North America
# 29          Europe
# ..             ...
# 133         Africa
# 134           Asia
# 135           Asia
# 136           Asia
# 137         Africa
# 138         Africa
# 139           Asia
# 140           Asia
# 141         Africa
# 142         Africa
# 143           Asia
# 144         Africa
# 145         Africa
# 146         Africa
# 147         Africa
# 148         Africa
# 149         Africa
# 150         Africa
# 151         Africa
# 152         Africa
# 153         Africa
# 154         Africa
# 155         Africa
# 156           Asia
# 157         Africa
# 158         Africa
# 159        Oceania
# 160         Africa
# 161         Africa
# 162         Europe
#
# [163 rows x 6 columns]

# %%
# Import the pandas library under its usual alias
import pandas as pd

# Load the business.csv file as a DataFrame called businesses
businesses = pd.read_csv("datasets/businesses.csv")
# Load countries.csv to a DataFrame
countries = pd.read_csv("datasets/countries.csv")

# Merge sorted_businesses with countries
businesses_countries = sorted_businesses.merge(countries , on='country_code')

# Filter businesses_countries to include countries in North America only
north_america = businesses_countries[businesses_countries['continent']== 'North America']
print(north_america.shape[0])
north_america.head()
# Out:
# 17
#                        business  year_founded category_code country_code  \
# 22  La Casa de Moneda de México          1534         CAT12          MEX
# 28           Shirley Plantation          1638          CAT1          USA
# 33         Hudson's Bay Company          1670         CAT17          CAN
# 35                Mount Gay Rum          1703          CAT9          BRB
# 40                    Rose Hall          1770         CAT19          JAM
#
#           country      continent
# 22         Mexico  North America
# 28  United States  North America
# 33         Canada  North America
# 35       Barbados  North America
# 40        Jamaica  North America

# %% [markdown]
# ## 3. The oldest business on each continent
# <p>Now we can see that the oldest company in North America is La Casa de Moneda de México, founded in 1534. Why stop there, though, when we could easily find out the oldest business on every continent? </p>

# %%
# Create continent, which lists only the continent and oldest year_founded
continent = businesses_countries.groupby("continent").agg({"year_founded":"min"})

# Merge continent with businesses_countries
merged_continent = continent.merge(businesses_countries, on=["continent", "year_founded"])

# Subset continent so that only the four columns of interest are included
subset_merged_continent = merged_continent[["continent", "country", "business", "year_founded"]]
subset_merged_continent
# Out:
#        continent    country                     business  year_founded
# 0         Africa  Mauritius               Mauritius Post          1772
# 1           Asia      Japan                   Kongō Gumi           578
# 2         Europe    Austria  St. Peter Stifts Kulinarium           803
# 3  North America     Mexico  La Casa de Moneda de México          1534
# 4        Oceania  Australia               Australia Post          1809
# 5  South America       Peru      Casa Nacional de Moneda          1565

# %%
# Create continent, which lists only the continent and oldest year_founded
continent = businesses_countries.groupby('continent').agg({'year_founded':'min'})

continent
# Out:
#                year_founded
# continent
# Africa                 1772
# Asia                    578
# Europe                  803
# North America          1534
# Oceania                1809
# South America          1565

# %%
# Merge continent with businesses_countries
merged_continent = continent.merge(businesses_countries,on=["continent", "year_founded"])
merged_continent
# Out:
#        continent  year_founded                     business category_code  \
# 0         Africa          1772               Mauritius Post         CAT16
# 1           Asia           578                   Kongō Gumi          CAT6
# 2         Europe           803  St. Peter Stifts Kulinarium          CAT4
# 3  North America          1534  La Casa de Moneda de México         CAT12
# 4        Oceania          1809               Australia Post         CAT16
# 5  South America          1565      Casa Nacional de Moneda          CAT3
#
#   country_code    country
# 0          MUS  Mauritius
# 1          JPN      Japan
# 2          AUT    Austria
# 3          MEX     Mexico
# 4          AUS  Australia
# 5          PER       Peru

# %%
# Subset continent so that only the four columns of interest are included
subset_merged_continent =merged_continent[['continent', 'country', 'business', 'year_founded']]
subset_merged_continent
# Out:
#        continent    country                     business  year_founded
# 0         Africa  Mauritius               Mauritius Post          1772
# 1           Asia      Japan                   Kongō Gumi           578
# 2         Europe    Austria  St. Peter Stifts Kulinarium           803
# 3  North America     Mexico  La Casa de Moneda de México          1534
# 4        Oceania  Australia               Australia Post          1809
# 5  South America       Peru      Casa Nacional de Moneda          1565

# %% [markdown]
# ## 4. Unknown oldest businesses
# <p>BusinessFinancing.co.uk wasn't able to determine the oldest business for some countries, and those countries are simply left off of <code>businesses.csv</code> and, by extension, <code>businesses</code>. However, the <code>countries</code> that we created <em>does</em> include all countries in the world, regardless of whether the oldest business is known. </p>
# <p>We can compare the two datasets in one DataFrame to find out which countries don't have a known oldest business! </p>

# %%
all_countries = businesses.merge(countries,on='country_code', how='right', indicator=True)
# Filter to include only countries without oldest businesses
missing_countries = all_countries[all_countries['_merge'] != 'both' ]

# Create a series of the country names with missing oldest business data
missing_countries_series = missing_countries['country']

# Display the series
missing_countries_series
print(all_countries)
# Out:
#                                            business  year_founded  \
# 0                                    Hamoud Boualem        1878.0
# 1                    Communauté Électrique du Bénin        1968.0
# 2                          Botswana Meat Commission        1965.0
# 3                                       Air Burkina        1967.0
# 4                                           Brarudi        1955.0
# 5                  Cameroon Development Corporation        1947.0
# 6                            Correios de Cabo Verde        1849.0
# 7        Banque Internationale pour la Centrafrique        1946.0
# 8                                        Cotontchad        1971.0
# 9                       Central Bank of the Comoros        1981.0
# 10    Société nationale des Chemins de fer du Congo        1889.0
# 11   Development Bank of the Central African States        1975.0
# 12                                         La Poste        1945.0
# 13                          Ethio-Djibouti Railways        1901.0
# 14                       Egyptian National Railways        1854.0
# 15                       Guinea Ecuatorial Airlines        1996.0
# 16                                   Asmara Brewery        1939.0
# 17                        National Bank of Ethiopia        1906.0
# 18                                   BGFIBank Group        1971.0
# 19                                     Halco Mining        1962.0
# 20                         Correios da Guiné-Bissau        1973.0
# 21                                KCB Group Limited        1896.0
# 22                          Central Bank of Lesotho        1978.0
# 23                          National Port Authority        1921.0
# 24                                        Umma Bank        1907.0
# 25                                   Air Madagascar        1962.0
# 26                  Malawi Broadcasting Corporation        1964.0
# 27      Office de Radiodiffusion-Télévision du Mali        1957.0
# 28                       Central Bank of Mauritania        1973.0
# 29                                   Mauritius Post        1772.0
# ..                                              ...           ...
# 165                                             NaN           NaN
# 166                                             NaN           NaN
# 167                                             NaN           NaN
# 168                                             NaN           NaN
# 169                                             NaN           NaN
# 170                                             NaN           NaN
# 171                                             NaN           NaN
# 172                                             NaN           NaN
# 173                                             NaN           NaN
# 174                                             NaN           NaN
# 175                                             NaN           NaN
# 176                                             NaN           NaN
# 177                                             NaN           NaN
# 178                                             NaN           NaN
# 179                                             NaN           NaN
# 180                                             NaN           NaN
# 181                                             NaN           NaN
# 182                                             NaN           NaN
# 183                                             NaN           NaN
# 184                                             NaN           NaN
# 185                                             NaN           NaN
# 186                                             NaN           NaN
# 187                                             NaN           NaN
# 188                                             NaN           NaN
# 189                                             NaN           NaN
# 190                                             NaN           NaN
# 191                                             NaN           NaN
# 192                                             NaN           NaN
# 193                                             NaN           NaN
# 194                                             NaN           NaN
#
#     category_code country_code                                country  \
# 0           CAT11          DZA                                Algeria
# 1           CAT10          BEN                                  Benin
# 2            CAT1          BWA                               Botswana
# 3            CAT2          BFA                           Burkina Faso
# 4            CAT9          BDI                                Burundi
# 5            CAT1          CMR                               Cameroon
# 6           CAT16          CPV                             Cabo Verde
# 7            CAT3          CAF               Central African Republic
# 8            CAT1          TCD                                   Chad
# 9            CAT3          COM                                Comoros
# 10           CAT2          COD  Congo, The Democratic Republic of the
# 11           CAT3          COG                                  Congo
# 12          CAT16          CIV                          Côte d'Ivoire
# 13           CAT2          DJI                               Djibouti
# 14           CAT2          EGY                                  Egypt
# 15           CAT2          GNQ                      Equatorial Guinea
# 16           CAT9          ERI                                Eritrea
# 17           CAT3          ETH                               Ethiopia
# 18           CAT3          GAB                                  Gabon
# 19          CAT15          GIN                                 Guinea
# 20          CAT16          GNB                          Guinea-Bissau
# 21           CAT3          KEN                                  Kenya
# 22           CAT3          LSO                                Lesotho
# 23           CAT2          LBR                                Liberia
# 24           CAT3          LBY                                  Libya
# 25           CAT2          MDG                             Madagascar
# 26          CAT13          MWI                                 Malawi
# 27          CAT13          MLI                                   Mali
# 28           CAT3          MRT                             Mauritania
# 29          CAT16          MUS                              Mauritius
# ..            ...          ...                                    ...
# 165           NaN          BHS                                Bahamas
# 166           NaN          DOM                     Dominican Republic
# 167           NaN          ECU                                Ecuador
# 168           NaN          FJI                                   Fiji
# 169           NaN          FSM        Micronesia, Federated States of
# 170           NaN          GHA                                  Ghana
# 171           NaN          GMB                                 Gambia
# 172           NaN          GRD                                Grenada
# 173           NaN          IRN              Iran, Islamic Republic of
# 174           NaN          KGZ                             Kyrgyzstan
# 175           NaN          KIR                               Kiribati
# 176           NaN          KNA                  Saint Kitts and Nevis
# 177           NaN          MCO                                 Monaco
# 178           NaN          MDA                   Moldova, Republic of
# 179           NaN          MDV                               Maldives
# 180           NaN          MHL                       Marshall Islands
# 181           NaN          NRU                                  Nauru
# 182           NaN          PLW                                  Palau
# 183           NaN          PNG                       Papua New Guinea
# 184           NaN          PRY                               Paraguay
# 185           NaN          PSE                    Palestine, State of
# 186           NaN          SLB                        Solomon Islands
# 187           NaN          SUR                               Suriname
# 188           NaN          TJK                             Tajikistan
# 189           NaN          TKM                           Turkmenistan
# 190           NaN          TLS                            Timor-Leste
# 191           NaN          TON                                  Tonga
# 192           NaN          TUV                                 Tuvalu
# 193           NaN          VCT       Saint Vincent and the Grenadines
# 194           NaN          WSM                                  Samoa
#
#          continent      _merge
# 0           Africa        both
# 1           Africa        both
# 2           Africa        both
# 3           Africa        both
# 4           Africa        both
# 5           Africa        both
# 6           Africa        both
# 7           Africa        both
# 8           Africa        both
# 9           Africa        both
# 10          Africa        both
# 11          Africa        both
# 12          Africa        both
# 13          Africa        both
# 14          Africa        both
# 15          Africa        both
# 16          Africa        both
# 17          Africa        both
# 18          Africa        both
# 19          Africa        both
# 20          Africa        both
# 21          Africa        both
# 22          Africa        both
# 23          Africa        both
# 24          Africa        both
# 25          Africa        both
# 26          Africa        both
# 27          Africa        both
# 28          Africa        both
# 29          Africa        both
# ..             ...         ...
# 165  North America  right_only
# 166  North America  right_only
# 167  South America  right_only
# 168        Oceania  right_only
# 169        Oceania  right_only
# 170         Africa  right_only
# 171         Africa  right_only
# 172  North America  right_only
# 173           Asia  right_only
# 174           Asia  right_only
# 175        Oceania  right_only
# 176  North America  right_only
# 177         Europe  right_only
# 178         Europe  right_only
# 179           Asia  right_only
# 180        Oceania  right_only
# 181        Oceania  right_only
# 182        Oceania  right_only
# 183        Oceania  right_only
# 184  South America  right_only
# 185           Asia  right_only
# 186        Oceania  right_only
# 187  South America  right_only
# 188           Asia  right_only
# 189           Asia  right_only
# 190           Asia  right_only
# 191        Oceania  right_only
# 192        Oceania  right_only
# 193  North America  right_only
# 194        Oceania  right_only
#
# [195 rows x 7 columns]

# %%
import pandas as pd
# Load the business.csv file as a DataFrame called businesses
businesses = pd.read_csv("datasets/businesses.csv")
# Load countries.csv to a DataFrame
countries = pd.read_csv("datasets/countries.csv")
# Use .merge() to create a DataFrame, all_countries
all_countries = businesses.merge(countries, on="country_code", how="right",  indicator=True)
# Filter to include only countries without oldest businesses
missing_countries = all_countries[all_countries["_merge"] != "both"]

# Create a series of the country names with missing oldest business data
missing_countries_series = missing_countries["country"]

# Display the series
missing_countries_series
# Out:
# 163                              Angola
# 164                 Antigua and Barbuda
# 165                             Bahamas
# 166                  Dominican Republic
# 167                             Ecuador
# 168                                Fiji
# 169     Micronesia, Federated States of
# 170                               Ghana
# 171                              Gambia
# 172                             Grenada
# 173           Iran, Islamic Republic of
# 174                          Kyrgyzstan
# 175                            Kiribati
# 176               Saint Kitts and Nevis
# 177                              Monaco
# 178                Moldova, Republic of
# 179                            Maldives
# 180                    Marshall Islands
# 181                               Nauru
# 182                               Palau
# 183                    Papua New Guinea
# 184                            Paraguay
# 185                 Palestine, State of
# 186                     Solomon Islands
# 187                            Suriname
# 188                          Tajikistan
# 189                        Turkmenistan
# 190                         Timor-Leste
# 191                               Tonga
# 192                              Tuvalu
# 193    Saint Vincent and the Grenadines
# 194                               Samoa
# Name: country, dtype: object

# %% [markdown]
# ## 5. Adding new oldest business data
# <p>It looks like we've got some holes in our dataset! Fortunately, we've taken it upon ourselves to improve upon BusinessFinancing.co.uk's work and find oldest businesses in a few of the missing countries. We've stored the newfound oldest businesses in <code>new_businesses</code>, located at <code>"datasets/new_businesses.csv"</code>. It has the exact same structure as our <code>businesses</code> dataset. </p>
# <h3 id="new_businesses"><code>new_businesses</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>business</code></td>
# <td>varchar</td>
# <td>Name of the business.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>year_founded</code></td>
# <td>int</td>
# <td>Year the business was founded.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>category_code</code></td>
# <td>varchar</td>
# <td>Code for the category of the business.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>country_code</code></td>
# <td>char</td>
# <td>ISO 3166-1 3-letter country code.</td>
# </tr>
# </tbody>
# </table>
# <p>All we have to do is combine the two so that we've got one more complete list of businesses!</p>

# %%
# Import new_businesses.csv
new_businesses = pd.read_csv("datasets/new_businesses.csv")

# Add the data in new_businesses to the existing businesses
all_businesses = pd.concat([new_businesses, businesses])

# Merge and filter to find countries with missing business data
new_all_countries = all_businesses.merge(countries, on="country_code", how="outer",  indicator=True)
new_missing_countries = new_all_countries[new_all_countries["_merge"] != "both"]

# Group by continent and create a "count_missing" column
count_missing = new_missing_countries.groupby("continent").agg({"country":"count"})
count_missing.columns = ["count_missing"]
count_missing
# Out:
#                count_missing
# continent
# Africa                     3
# Asia                       7
# Europe                     2
# North America              5
# Oceania                   10
# South America              3

# %%
# Import new_businesses.csv
new_businesses = pd.read_csv("datasets/new_businesses.csv")
new_businesses
# Out:
#                     business  year_founded category_code country_code
# 0                 Fiji Times          1869         CAT13          FJI
# 1  J. Armando Bermúdez & Co.          1852          CAT9          DOM

# %%
# Add the data in new_businesses to the existing businesses
all_businesses = pd.concat([new_businesses, businesses])
all_businesses
# Out:
#                                            business  year_founded  \
# 0                                        Fiji Times          1869
# 1                         J. Armando Bermúdez & Co.          1852
# 0                                    Hamoud Boualem          1878
# 1                    Communauté Électrique du Bénin          1968
# 2                          Botswana Meat Commission          1965
# 3                                       Air Burkina          1967
# 4                                           Brarudi          1955
# 5                  Cameroon Development Corporation          1947
# 6                            Correios de Cabo Verde          1849
# 7        Banque Internationale pour la Centrafrique          1946
# 8                                        Cotontchad          1971
# 9                       Central Bank of the Comoros          1981
# 10    Société nationale des Chemins de fer du Congo          1889
# 11   Development Bank of the Central African States          1975
# 12                                         La Poste          1945
# 13                          Ethio-Djibouti Railways          1901
# 14                       Egyptian National Railways          1854
# 15                       Guinea Ecuatorial Airlines          1996
# 16                                   Asmara Brewery          1939
# 17                        National Bank of Ethiopia          1906
# 18                                   BGFIBank Group          1971
# 19                                     Halco Mining          1962
# 20                         Correios da Guiné-Bissau          1973
# 21                                KCB Group Limited          1896
# 22                          Central Bank of Lesotho          1978
# 23                          National Port Authority          1921
# 24                                        Umma Bank          1907
# 25                                   Air Madagascar          1962
# 26                  Malawi Broadcasting Corporation          1964
# 27      Office de Radiodiffusion-Télévision du Mali          1957
# ..                                              ...           ...
# 133                            Drohobych salt plant          1250
# 134                                   Mount Gay Rum          1703
# 135                                     Belize Bank          1902
# 136                            Hudson's Bay Company          1670
# 137                    Florida Ice and Farm Company          1908
# 138                              Cubana de Aviación          1929
# 139                        The Chronicle (Dominica)          1909
# 140                                HSBC El Salvador          1891
# 141                   Corporación Multi Inversiones          1920
# 142                                Rhum Barbancourt          1862
# 143                   National Railroad of Honduras          1870
# 144                                       Rose Hall          1770
# 145                     La Casa de Moneda de México          1534
# 146                                    Flor de Caña          1890
# 147                         National Bank of Panama          1904
# 148                   1st National Bank of St Lucia          1938
# 149                              House of Angostura          1830
# 150                              Shirley Plantation          1638
# 151            Bank of the Province of Buenos Aires          1822
# 152                       Banco Nacional de Bolivia          1871
# 153                         Casa da Moeda do Brasil          1694
# 154                                           Famae          1811
# 155                      Casa de Moneda de Colombia          1621
# 156                                       Banks DIH          1840
# 157                         Casa Nacional de Moneda          1565
# 158                                  Cafe Brasilero          1877
# 159                                  Hacienda Chuao          1660
# 160                                  Australia Post          1809
# 161                             Bank of New Zealand          1861
# 162                          European Trust Company          1991
#
#     category_code country_code
# 0           CAT13          FJI
# 1            CAT9          DOM
# 0           CAT11          DZA
# 1           CAT10          BEN
# 2            CAT1          BWA
# 3            CAT2          BFA
# 4            CAT9          BDI
# 5            CAT1          CMR
# 6           CAT16          CPV
# 7            CAT3          CAF
# 8            CAT1          TCD
# 9            CAT3          COM
# 10           CAT2          COD
# 11           CAT3          COG
# 12          CAT16          CIV
# 13           CAT2          DJI
# 14           CAT2          EGY
# 15           CAT2          GNQ
# 16           CAT9          ERI
# 17           CAT3          ETH
# 18           CAT3          GAB
# 19          CAT15          GIN
# 20          CAT16          GNB
# 21           CAT3          KEN
# 22           CAT3          LSO
# 23           CAT2          LBR
# 24           CAT3          LBY
# 25           CAT2          MDG
# 26          CAT13          MWI
# 27          CAT13          MLI
# ..            ...          ...
# 133         CAT12          UKR
# 134          CAT9          BRB
# 135          CAT3          BLZ
# 136         CAT17          CAN
# 137          CAT9          CRI
# 138          CAT2          CUB
# 139         CAT13          DMA
# 140          CAT3          SLV
# 141         CAT11          GTM
# 142          CAT9          HTI
# 143          CAT2          HND
# 144         CAT19          JAM
# 145         CAT12          MEX
# 146          CAT9          NIC
# 147          CAT3          PAN
# 148          CAT3          LCA
# 149          CAT9          TTO
# 150          CAT1          USA
# 151          CAT3          ARG
# 152          CAT3          BOL
# 153         CAT12          BRA
# 154          CAT8          CHL
# 155         CAT12          COL
# 156         CAT11          GUY
# 157          CAT3          PER
# 158          CAT4          URY
# 159         CAT11          VEN
# 160         CAT16          AUS
# 161          CAT3          NZL
# 162          CAT3          VUT
#
# [165 rows x 4 columns]

# %%
# Merge and filter to find countries with missing business data
new_all_countries = all_businesses.merge(countries, on="country_code", how="outer",  indicator=True)
new_all_countries
# Out:
#                                            business  year_founded  \
# 0                                        Fiji Times        1869.0
# 1                         J. Armando Bermúdez & Co.        1852.0
# 2                                    Hamoud Boualem        1878.0
# 3                    Communauté Électrique du Bénin        1968.0
# 4                          Botswana Meat Commission        1965.0
# 5                                       Air Burkina        1967.0
# 6                                           Brarudi        1955.0
# 7                  Cameroon Development Corporation        1947.0
# 8                            Correios de Cabo Verde        1849.0
# 9        Banque Internationale pour la Centrafrique        1946.0
# 10                                       Cotontchad        1971.0
# 11                      Central Bank of the Comoros        1981.0
# 12    Société nationale des Chemins de fer du Congo        1889.0
# 13   Development Bank of the Central African States        1975.0
# 14                                         La Poste        1945.0
# 15                          Ethio-Djibouti Railways        1901.0
# 16                       Egyptian National Railways        1854.0
# 17                       Guinea Ecuatorial Airlines        1996.0
# 18                                   Asmara Brewery        1939.0
# 19                        National Bank of Ethiopia        1906.0
# 20                                   BGFIBank Group        1971.0
# 21                                     Halco Mining        1962.0
# 22                         Correios da Guiné-Bissau        1973.0
# 23                                KCB Group Limited        1896.0
# 24                          Central Bank of Lesotho        1978.0
# 25                          National Port Authority        1921.0
# 26                                        Umma Bank        1907.0
# 27                                   Air Madagascar        1962.0
# 28                  Malawi Broadcasting Corporation        1964.0
# 29      Office de Radiodiffusion-Télévision du Mali        1957.0
# ..                                              ...           ...
# 165                                             NaN           NaN
# 166                                             NaN           NaN
# 167                                             NaN           NaN
# 168                                             NaN           NaN
# 169                                             NaN           NaN
# 170                                             NaN           NaN
# 171                                             NaN           NaN
# 172                                             NaN           NaN
# 173                                             NaN           NaN
# 174                                             NaN           NaN
# 175                                             NaN           NaN
# 176                                             NaN           NaN
# 177                                             NaN           NaN
# 178                                             NaN           NaN
# 179                                             NaN           NaN
# 180                                             NaN           NaN
# 181                                             NaN           NaN
# 182                                             NaN           NaN
# 183                                             NaN           NaN
# 184                                             NaN           NaN
# 185                                             NaN           NaN
# 186                                             NaN           NaN
# 187                                             NaN           NaN
# 188                                             NaN           NaN
# 189                                             NaN           NaN
# 190                                             NaN           NaN
# 191                                             NaN           NaN
# 192                                             NaN           NaN
# 193                                             NaN           NaN
# 194                                             NaN           NaN
#
#     category_code country_code                                country  \
# 0           CAT13          FJI                                   Fiji
# 1            CAT9          DOM                     Dominican Republic
# 2           CAT11          DZA                                Algeria
# 3           CAT10          BEN                                  Benin
# 4            CAT1          BWA                               Botswana
# 5            CAT2          BFA                           Burkina Faso
# 6            CAT9          BDI                                Burundi
# 7            CAT1          CMR                               Cameroon
# 8           CAT16          CPV                             Cabo Verde
# 9            CAT3          CAF               Central African Republic
# 10           CAT1          TCD                                   Chad
# 11           CAT3          COM                                Comoros
# 12           CAT2          COD  Congo, The Democratic Republic of the
# 13           CAT3          COG                                  Congo
# 14          CAT16          CIV                          Côte d'Ivoire
# 15           CAT2          DJI                               Djibouti
# 16           CAT2          EGY                                  Egypt
# 17           CAT2          GNQ                      Equatorial Guinea
# 18           CAT9          ERI                                Eritrea
# 19           CAT3          ETH                               Ethiopia
# 20           CAT3          GAB                                  Gabon
# 21          CAT15          GIN                                 Guinea
# 22          CAT16          GNB                          Guinea-Bissau
# 23           CAT3          KEN                                  Kenya
# 24           CAT3          LSO                                Lesotho
# 25           CAT2          LBR                                Liberia
# 26           CAT3          LBY                                  Libya
# 27           CAT2          MDG                             Madagascar
# 28          CAT13          MWI                                 Malawi
# 29          CAT13          MLI                                   Mali
# ..            ...          ...                                    ...
# 165           NaN          AGO                                 Angola
# 166           NaN          ATG                    Antigua and Barbuda
# 167           NaN          BHS                                Bahamas
# 168           NaN          ECU                                Ecuador
# 169           NaN          FSM        Micronesia, Federated States of
# 170           NaN          GHA                                  Ghana
# 171           NaN          GMB                                 Gambia
# 172           NaN          GRD                                Grenada
# 173           NaN          IRN              Iran, Islamic Republic of
# 174           NaN          KGZ                             Kyrgyzstan
# 175           NaN          KIR                               Kiribati
# 176           NaN          KNA                  Saint Kitts and Nevis
# 177           NaN          MCO                                 Monaco
# 178           NaN          MDA                   Moldova, Republic of
# 179           NaN          MDV                               Maldives
# 180           NaN          MHL                       Marshall Islands
# 181           NaN          NRU                                  Nauru
# 182           NaN          PLW                                  Palau
# 183           NaN          PNG                       Papua New Guinea
# 184           NaN          PRY                               Paraguay
# 185           NaN          PSE                    Palestine, State of
# 186           NaN          SLB                        Solomon Islands
# 187           NaN          SUR                               Suriname
# 188           NaN          TJK                             Tajikistan
# 189           NaN          TKM                           Turkmenistan
# 190           NaN          TLS                            Timor-Leste
# 191           NaN          TON                                  Tonga
# 192           NaN          TUV                                 Tuvalu
# 193           NaN          VCT       Saint Vincent and the Grenadines
# 194           NaN          WSM                                  Samoa
#
#          continent      _merge
# 0          Oceania        both
# 1    North America        both
# 2           Africa        both
# 3           Africa        both
# 4           Africa        both
# 5           Africa        both
# 6           Africa        both
# 7           Africa        both
# 8           Africa        both
# 9           Africa        both
# 10          Africa        both
# 11          Africa        both
# 12          Africa        both
# 13          Africa        both
# 14          Africa        both
# 15          Africa        both
# 16          Africa        both
# 17          Africa        both
# 18          Africa        both
# 19          Africa        both
# 20          Africa        both
# 21          Africa        both
# 22          Africa        both
# 23          Africa        both
# 24          Africa        both
# 25          Africa        both
# 26          Africa        both
# 27          Africa        both
# 28          Africa        both
# 29          Africa        both
# ..             ...         ...
# 165         Africa  right_only
# 166  North America  right_only
# 167  North America  right_only
# 168  South America  right_only
# 169        Oceania  right_only
# 170         Africa  right_only
# 171         Africa  right_only
# 172  North America  right_only
# 173           Asia  right_only
# 174           Asia  right_only
# 175        Oceania  right_only
# 176  North America  right_only
# 177         Europe  right_only
# 178         Europe  right_only
# 179           Asia  right_only
# 180        Oceania  right_only
# 181        Oceania  right_only
# 182        Oceania  right_only
# 183        Oceania  right_only
# 184  South America  right_only
# 185           Asia  right_only
# 186        Oceania  right_only
# 187  South America  right_only
# 188           Asia  right_only
# 189           Asia  right_only
# 190           Asia  right_only
# 191        Oceania  right_only
# 192        Oceania  right_only
# 193  North America  right_only
# 194        Oceania  right_only
#
# [195 rows x 7 columns]

# %%
new_missing_countries = new_all_countries[new_all_countries["_merge"] != "both"]
new_missing_countries
# Out:
#     business  year_founded category_code country_code  \
# 165      NaN           NaN           NaN          AGO
# 166      NaN           NaN           NaN          ATG
# 167      NaN           NaN           NaN          BHS
# 168      NaN           NaN           NaN          ECU
# 169      NaN           NaN           NaN          FSM
# 170      NaN           NaN           NaN          GHA
# 171      NaN           NaN           NaN          GMB
# 172      NaN           NaN           NaN          GRD
# 173      NaN           NaN           NaN          IRN
# 174      NaN           NaN           NaN          KGZ
# 175      NaN           NaN           NaN          KIR
# 176      NaN           NaN           NaN          KNA
# 177      NaN           NaN           NaN          MCO
# 178      NaN           NaN           NaN          MDA
# 179      NaN           NaN           NaN          MDV
# 180      NaN           NaN           NaN          MHL
# 181      NaN           NaN           NaN          NRU
# 182      NaN           NaN           NaN          PLW
# 183      NaN           NaN           NaN          PNG
# 184      NaN           NaN           NaN          PRY
# 185      NaN           NaN           NaN          PSE
# 186      NaN           NaN           NaN          SLB
# 187      NaN           NaN           NaN          SUR
# 188      NaN           NaN           NaN          TJK
# 189      NaN           NaN           NaN          TKM
# 190      NaN           NaN           NaN          TLS
# 191      NaN           NaN           NaN          TON
# 192      NaN           NaN           NaN          TUV
# 193      NaN           NaN           NaN          VCT
# 194      NaN           NaN           NaN          WSM
#
#                               country      continent      _merge
# 165                            Angola         Africa  right_only
# 166               Antigua and Barbuda  North America  right_only
# 167                           Bahamas  North America  right_only
# 168                           Ecuador  South America  right_only
# 169   Micronesia, Federated States of        Oceania  right_only
# 170                             Ghana         Africa  right_only
# 171                            Gambia         Africa  right_only
# 172                           Grenada  North America  right_only
# 173         Iran, Islamic Republic of           Asia  right_only
# 174                        Kyrgyzstan           Asia  right_only
# 175                          Kiribati        Oceania  right_only
# 176             Saint Kitts and Nevis  North America  right_only
# 177                            Monaco         Europe  right_only
# 178              Moldova, Republic of         Europe  right_only
# 179                          Maldives           Asia  right_only
# 180                  Marshall Islands        Oceania  right_only
# 181                             Nauru        Oceania  right_only
# 182                             Palau        Oceania  right_only
# 183                  Papua New Guinea        Oceania  right_only
# 184                          Paraguay  South America  right_only
# 185               Palestine, State of           Asia  right_only
# 186                   Solomon Islands        Oceania  right_only
# 187                          Suriname  South America  right_only
# 188                        Tajikistan           Asia  right_only
# 189                      Turkmenistan           Asia  right_only
# 190                       Timor-Leste           Asia  right_only
# 191                             Tonga        Oceania  right_only
# 192                            Tuvalu        Oceania  right_only
# 193  Saint Vincent and the Grenadines  North America  right_only
# 194                             Samoa        Oceania  right_only

# %%
# Group by continent and create a "count_missing" column
count_missing = new_missing_countries.groupby("continent").agg({"country":"count"})
count_missing
# Out:
#                country
# continent
# Africa               3
# Asia                 7
# Europe               2
# North America        5
# Oceania             10
# South America        3

# %%
count_missing.columns = ["count_missing"]
count_missing
# Out:
#                count_missing
# continent
# Africa                     3
# Asia                       7
# Europe                     2
# North America              5
# Oceania                   10
# South America              3

# %% [markdown]
# ## 6. The oldest industries
# <p>Remember our oldest business in the world, Kongō Gumi? </p>
# <table>
# <thead>
# <tr>
# <th style="text-align:right;"></th>
# <th style="text-align:left;">business</th>
# <th style="text-align:right;">year_founded</th>
# <th style="text-align:left;">category_code</th>
# <th style="text-align:left;">country_code</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:right;">64</td>
# <td style="text-align:left;">Kongō Gumi</td>
# <td style="text-align:right;">578</td>
# <td style="text-align:left;">CAT6</td>
# <td style="text-align:left;">JPN</td>
# </tr>
# </tbody>
# </table>
# <p>We know Kongō Gumi was founded in the year 578 in Japan, but it's a little hard to decipher which industry it's in. Information about what the <code>category_code</code> column refers to is in <code>"datasets/categories.csv"</code>: </p>
# <h3 id="categories"><code>categories</code></h3>
# <table>
# <thead>
# <tr>
# <th style="text-align:left;">column</th>
# <th>type</th>
# <th>meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:left;"><code>category_code</code></td>
# <td>varchar</td>
# <td>Code for the category of the business.</td>
# </tr>
# <tr>
# <td style="text-align:left;"><code>category</code></td>
# <td>varchar</td>
# <td>Description of the business category.</td>
# </tr>
# </tbody>
# </table>
# <p>Let's use <code>categories.csv</code> to understand how many oldest businesses are in each category of industry.</p>

# %%
# Import categories.csv and merge to businesses
categories=pd.read_csv("datasets/categories.csv")
categories
# Out:
#    category_code                           category
# 0           CAT1                        Agriculture
# 1           CAT2               Aviation & Transport
# 2           CAT3                  Banking & Finance
# 3           CAT4          Cafés, Restaurants & Bars
# 4           CAT5                       Conglomerate
# 5           CAT6                       Construction
# 6           CAT7                     Consumer Goods
# 7           CAT8                            Defense
# 8           CAT9  Distillers, Vintners, & Breweries
# 9          CAT10                             Energy
# 10         CAT11                   Food & Beverages
# 11         CAT12         Manufacturing & Production
# 12         CAT13                              Media
# 13         CAT14                            Medical
# 14         CAT15                             Mining
# 15         CAT16                     Postal Service
# 16         CAT17                             Retail
# 17         CAT18                 Telecommunications
# 18         CAT19                   Tourism & Hotels

# %%
businesses_categories=businesses.merge(categories,on='category_code',)
businesses_categories
# Out:
#                                           business  year_founded  \
# 0                                   Hamoud Boualem          1878
# 1                           M. M. Ispahani Limited          1820
# 2                             George Steuart Group          1835
# 3                    Corporación Multi Inversiones          1920
# 4                                        Banks DIH          1840
# 5                                   Hacienda Chuao          1660
# 6                   Communauté Électrique du Bénin          1968
# 7                                North Oil Company          1928
# 8                              Electricite du Laos          1959
# 9                       Petroleum Development Oman          1937
# 10                        Botswana Meat Commission          1965
# 11                Cameroon Development Corporation          1947
# 12                                      Cotontchad          1971
# 13                          Spinzar Cotton Company          1930
# 14                               Casa de Ganaderos          1218
# 15                              Shirley Plantation          1638
# 16                                     Air Burkina          1967
# 17   Société nationale des Chemins de fer du Congo          1889
# 18                         Ethio-Djibouti Railways          1901
# 19                      Egyptian National Railways          1854
# 20                      Guinea Ecuatorial Airlines          1996
# 21                         National Port Authority          1921
# 22                                  Air Madagascar          1962
# 23                      Beira Railroad Corporation          1892
# 24                             Dakar–Niger Railway          1924
# 25                                  Air Seychelles          1977
# 26                                      Swazi Rail          1963
# 27             Azerbaijan Caspian Shipping Company          1858
# 28                                     Tashi Group          1959
# 29                       Myanmar National Airlines          1948
# ..                                             ...           ...
# 133                        Casa da Moeda do Brasil          1694
# 134                     Casa de Moneda de Colombia          1621
# 135                                           BMMI          1883
# 136                        Hua Ho Department Store          1947
# 137                               M.H. Alshaya Co.          1890
# 138                           Hudson's Bay Company          1670
# 139             Ma Yu Ching's Bucket Chicken House          1153
# 140                                 Café Abu Salem          1914
# 141                                        Bakdash          1885
# 142                    St. Peter Stifts Kulinarium           803
# 143                                     Sean's Bar           900
# 144                                 Cafe Brasilero          1877
# 145                                         Pindad          1808
# 146                                     Arsenal AD          1878
# 147                                          Famae          1811
# 148                                     Kongō Gumi           578
# 149                               House of Alireza          1845
# 150                                 House of Habib          1841
# 151         Salam International Investment Limited          1952
# 152                                  B.Grimm Group          1878
# 153                     Petrodvorets Watch Factory          1721
# 154                                        Fiskars          1649
# 155                       Tutunski kombinat Prilep          1873
# 156                                 KT Corporation          1885
# 157                                     ALBtelecom          1912
# 158                                      Raeapteek          1422
# 159                                Gostilna Gastuž          1467
# 160                                Gasthof Sternen          1230
# 161                             Çemberlitaş Hamamı          1584
# 162                                      Rose Hall          1770
#
#     category_code country_code                    category
# 0           CAT11          DZA            Food & Beverages
# 1           CAT11          BGD            Food & Beverages
# 2           CAT11          LKA            Food & Beverages
# 3           CAT11          GTM            Food & Beverages
# 4           CAT11          GUY            Food & Beverages
# 5           CAT11          VEN            Food & Beverages
# 6           CAT10          BEN                      Energy
# 7           CAT10          IRQ                      Energy
# 8           CAT10          LAO                      Energy
# 9           CAT10          OMN                      Energy
# 10           CAT1          BWA                 Agriculture
# 11           CAT1          CMR                 Agriculture
# 12           CAT1          TCD                 Agriculture
# 13           CAT1          AFG                 Agriculture
# 14           CAT1          ESP                 Agriculture
# 15           CAT1          USA                 Agriculture
# 16           CAT2          BFA        Aviation & Transport
# 17           CAT2          COD        Aviation & Transport
# 18           CAT2          DJI        Aviation & Transport
# 19           CAT2          EGY        Aviation & Transport
# 20           CAT2          GNQ        Aviation & Transport
# 21           CAT2          LBR        Aviation & Transport
# 22           CAT2          MDG        Aviation & Transport
# 23           CAT2          MOZ        Aviation & Transport
# 24           CAT2          SEN        Aviation & Transport
# 25           CAT2          SYC        Aviation & Transport
# 26           CAT2          SWZ        Aviation & Transport
# 27           CAT2          AZE        Aviation & Transport
# 28           CAT2          BTN        Aviation & Transport
# 29           CAT2          MMR        Aviation & Transport
# ..            ...          ...                         ...
# 133         CAT12          BRA  Manufacturing & Production
# 134         CAT12          COL  Manufacturing & Production
# 135         CAT17          BHR                      Retail
# 136         CAT17          BRN                      Retail
# 137         CAT17          KWT                      Retail
# 138         CAT17          CAN                      Retail
# 139          CAT4          CHN   Cafés, Restaurants & Bars
# 140          CAT4          ISR   Cafés, Restaurants & Bars
# 141          CAT4          SYR   Cafés, Restaurants & Bars
# 142          CAT4          AUT   Cafés, Restaurants & Bars
# 143          CAT4          IRL   Cafés, Restaurants & Bars
# 144          CAT4          URY   Cafés, Restaurants & Bars
# 145          CAT8          IDN                     Defense
# 146          CAT8          BGR                     Defense
# 147          CAT8          CHL                     Defense
# 148          CAT6          JPN                Construction
# 149          CAT6          SAU                Construction
# 150          CAT5          PAK                Conglomerate
# 151          CAT5          QAT                Conglomerate
# 152          CAT5          THA                Conglomerate
# 153          CAT7          RUS              Consumer Goods
# 154          CAT7          FIN              Consumer Goods
# 155          CAT7          MKD              Consumer Goods
# 156         CAT18          KOR          Telecommunications
# 157         CAT18          ALB          Telecommunications
# 158         CAT14          EST                     Medical
# 159         CAT19          SVN            Tourism & Hotels
# 160         CAT19          CHE            Tourism & Hotels
# 161         CAT19          TUR            Tourism & Hotels
# 162         CAT19          JAM            Tourism & Hotels
#
# [163 rows x 5 columns]

# %%
# Create a DataFrame which lists the number of oldest businesses in each category
count_business_cats=businesses_categories.groupby('category').agg({'business':'count'})
count_business_cats
# Out:
#                                    business
# category
# Agriculture                               6
# Aviation & Transport                     19
# Banking & Finance                        37
# Cafés, Restaurants & Bars                 6
# Conglomerate                              3
# Construction                              2
# Consumer Goods                            3
# Defense                                   3
# Distillers, Vintners, & Breweries        22
# Energy                                    4
# Food & Beverages                          6
# Manufacturing & Production               15
# Media                                     7
# Medical                                   1
# Mining                                    3
# Postal Service                           16
# Retail                                    4
# Telecommunications                        2
# Tourism & Hotels                          4

# %%
# Create a DataFrame which lists the cumulative years that businesses from each category have been operating
years_business_cats=businesses_categories.groupby('category').agg({'year_founded':'sum'})
years_business_cats
# Out:
#                                    year_founded
# category
# Agriculture                               10669
# Aviation & Transport                      36598
# Banking & Finance                         70302
# Cafés, Restaurants & Bars                  8532
# Conglomerate                               5671
# Construction                               2423
# Consumer Goods                             5243
# Defense                                    5497
# Distillers, Vintners, & Breweries         37292
# Energy                                     7792
# Food & Beverages                          10953
# Manufacturing & Production                21854
# Media                                     13663
# Medical                                    1422
# Mining                                     5123
# Postal Service                            29113
# Retail                                     7390
# Telecommunications                         3797
# Tourism & Hotels                           6051

# %%
count_business_cats.columns=['count']
years_business_cats.columns= ['total_years_in_business']
display(count_business_cats.head(), years_business_cats.head())
# Out:
#                            count
# category
# Agriculture                    6
# Aviation & Transport          19
# Banking & Finance             37
# Cafés, Restaurants & Bars      6
# Conglomerate                   3
#                            total_years_in_business
# category
# Agriculture                                  10669
# Aviation & Transport                         36598
# Banking & Finance                            70302
# Cafés, Restaurants & Bars                     8532
# Conglomerate                                  5671

# %% [markdown]
# ## 7. Restaurant representation
# <p>No matter how we measure it, looks like Banking and Finance is an excellent industry to be in if longevity is our goal! Let's zoom in on another industry: cafés, restaurants, and bars. Which restaurants in our dataset have been around since before the year 1800?</p>

# %%
businesses_categories
# Out:
#                                           business  year_founded  \
# 0                                   Hamoud Boualem          1878
# 1                           M. M. Ispahani Limited          1820
# 2                             George Steuart Group          1835
# 3                    Corporación Multi Inversiones          1920
# 4                                        Banks DIH          1840
# 5                                   Hacienda Chuao          1660
# 6                   Communauté Électrique du Bénin          1968
# 7                                North Oil Company          1928
# 8                              Electricite du Laos          1959
# 9                       Petroleum Development Oman          1937
# 10                        Botswana Meat Commission          1965
# 11                Cameroon Development Corporation          1947
# 12                                      Cotontchad          1971
# 13                          Spinzar Cotton Company          1930
# 14                               Casa de Ganaderos          1218
# 15                              Shirley Plantation          1638
# 16                                     Air Burkina          1967
# 17   Société nationale des Chemins de fer du Congo          1889
# 18                         Ethio-Djibouti Railways          1901
# 19                      Egyptian National Railways          1854
# 20                      Guinea Ecuatorial Airlines          1996
# 21                         National Port Authority          1921
# 22                                  Air Madagascar          1962
# 23                      Beira Railroad Corporation          1892
# 24                             Dakar–Niger Railway          1924
# 25                                  Air Seychelles          1977
# 26                                      Swazi Rail          1963
# 27             Azerbaijan Caspian Shipping Company          1858
# 28                                     Tashi Group          1959
# 29                       Myanmar National Airlines          1948
# ..                                             ...           ...
# 133                        Casa da Moeda do Brasil          1694
# 134                     Casa de Moneda de Colombia          1621
# 135                                           BMMI          1883
# 136                        Hua Ho Department Store          1947
# 137                               M.H. Alshaya Co.          1890
# 138                           Hudson's Bay Company          1670
# 139             Ma Yu Ching's Bucket Chicken House          1153
# 140                                 Café Abu Salem          1914
# 141                                        Bakdash          1885
# 142                    St. Peter Stifts Kulinarium           803
# 143                                     Sean's Bar           900
# 144                                 Cafe Brasilero          1877
# 145                                         Pindad          1808
# 146                                     Arsenal AD          1878
# 147                                          Famae          1811
# 148                                     Kongō Gumi           578
# 149                               House of Alireza          1845
# 150                                 House of Habib          1841
# 151         Salam International Investment Limited          1952
# 152                                  B.Grimm Group          1878
# 153                     Petrodvorets Watch Factory          1721
# 154                                        Fiskars          1649
# 155                       Tutunski kombinat Prilep          1873
# 156                                 KT Corporation          1885
# 157                                     ALBtelecom          1912
# 158                                      Raeapteek          1422
# 159                                Gostilna Gastuž          1467
# 160                                Gasthof Sternen          1230
# 161                             Çemberlitaş Hamamı          1584
# 162                                      Rose Hall          1770
#
#     category_code country_code                    category
# 0           CAT11          DZA            Food & Beverages
# 1           CAT11          BGD            Food & Beverages
# 2           CAT11          LKA            Food & Beverages
# 3           CAT11          GTM            Food & Beverages
# 4           CAT11          GUY            Food & Beverages
# 5           CAT11          VEN            Food & Beverages
# 6           CAT10          BEN                      Energy
# 7           CAT10          IRQ                      Energy
# 8           CAT10          LAO                      Energy
# 9           CAT10          OMN                      Energy
# 10           CAT1          BWA                 Agriculture
# 11           CAT1          CMR                 Agriculture
# 12           CAT1          TCD                 Agriculture
# 13           CAT1          AFG                 Agriculture
# 14           CAT1          ESP                 Agriculture
# 15           CAT1          USA                 Agriculture
# 16           CAT2          BFA        Aviation & Transport
# 17           CAT2          COD        Aviation & Transport
# 18           CAT2          DJI        Aviation & Transport
# 19           CAT2          EGY        Aviation & Transport
# 20           CAT2          GNQ        Aviation & Transport
# 21           CAT2          LBR        Aviation & Transport
# 22           CAT2          MDG        Aviation & Transport
# 23           CAT2          MOZ        Aviation & Transport
# 24           CAT2          SEN        Aviation & Transport
# 25           CAT2          SYC        Aviation & Transport
# 26           CAT2          SWZ        Aviation & Transport
# 27           CAT2          AZE        Aviation & Transport
# 28           CAT2          BTN        Aviation & Transport
# 29           CAT2          MMR        Aviation & Transport
# ..            ...          ...                         ...
# 133         CAT12          BRA  Manufacturing & Production
# 134         CAT12          COL  Manufacturing & Production
# 135         CAT17          BHR                      Retail
# 136         CAT17          BRN                      Retail
# 137         CAT17          KWT                      Retail
# 138         CAT17          CAN                      Retail
# 139          CAT4          CHN   Cafés, Restaurants & Bars
# 140          CAT4          ISR   Cafés, Restaurants & Bars
# 141          CAT4          SYR   Cafés, Restaurants & Bars
# 142          CAT4          AUT   Cafés, Restaurants & Bars
# 143          CAT4          IRL   Cafés, Restaurants & Bars
# 144          CAT4          URY   Cafés, Restaurants & Bars
# 145          CAT8          IDN                     Defense
# 146          CAT8          BGR                     Defense
# 147          CAT8          CHL                     Defense
# 148          CAT6          JPN                Construction
# 149          CAT6          SAU                Construction
# 150          CAT5          PAK                Conglomerate
# 151          CAT5          QAT                Conglomerate
# 152          CAT5          THA                Conglomerate
# 153          CAT7          RUS              Consumer Goods
# 154          CAT7          FIN              Consumer Goods
# 155          CAT7          MKD              Consumer Goods
# 156         CAT18          KOR          Telecommunications
# 157         CAT18          ALB          Telecommunications
# 158         CAT14          EST                     Medical
# 159         CAT19          SVN            Tourism & Hotels
# 160         CAT19          CHE            Tourism & Hotels
# 161         CAT19          TUR            Tourism & Hotels
# 162         CAT19          JAM            Tourism & Hotels
#
# [163 rows x 5 columns]

# %%
# Filter using .query() for CAT4 businesses founded before 1800; sort results
old_restaurants = businesses_categories.query('year_founded < 1800 and category_code == "CAT4"')
old_restaurants
# Out:
#                                business  year_founded category_code  \
# 139  Ma Yu Ching's Bucket Chicken House          1153          CAT4
# 142         St. Peter Stifts Kulinarium           803          CAT4
# 143                          Sean's Bar           900          CAT4
#
#     country_code                   category
# 139          CHN  Cafés, Restaurants & Bars
# 142          AUT  Cafés, Restaurants & Bars
# 143          IRL  Cafés, Restaurants & Bars

# %%
# Sort the DataFrame
old_restaurants = old_restaurants.sort_values('year_founded')
old_restaurants
# Out:
#                                business  year_founded category_code  \
# 142         St. Peter Stifts Kulinarium           803          CAT4
# 143                          Sean's Bar           900          CAT4
# 139  Ma Yu Ching's Bucket Chicken House          1153          CAT4
#
#     country_code                   category
# 142          AUT  Cafés, Restaurants & Bars
# 143          IRL  Cafés, Restaurants & Bars
# 139          CHN  Cafés, Restaurants & Bars

# %% [markdown]
# ## 8. Categories and continents
# <p>St. Peter Stifts Kulinarium is old enough that the restaurant is believed to have served Mozart - and it would have been over 900 years old even when he was a patron! Let's finish by looking at the oldest business in each category of commerce for each continent. </p>

# %%
# Merge all businesses, countries, and categories together
businesses_categories_countries = businesses_categories.merge(countries,on='country_code')
businesses_categories_countries
# Out:
#                                           business  year_founded  \
# 0                                   Hamoud Boualem          1878
# 1                           M. M. Ispahani Limited          1820
# 2                             George Steuart Group          1835
# 3                    Corporación Multi Inversiones          1920
# 4                                        Banks DIH          1840
# 5                                   Hacienda Chuao          1660
# 6                   Communauté Électrique du Bénin          1968
# 7                                North Oil Company          1928
# 8                              Electricite du Laos          1959
# 9                       Petroleum Development Oman          1937
# 10                        Botswana Meat Commission          1965
# 11                Cameroon Development Corporation          1947
# 12                                      Cotontchad          1971
# 13                          Spinzar Cotton Company          1930
# 14                               Casa de Ganaderos          1218
# 15                              Shirley Plantation          1638
# 16                                     Air Burkina          1967
# 17   Société nationale des Chemins de fer du Congo          1889
# 18                         Ethio-Djibouti Railways          1901
# 19                      Egyptian National Railways          1854
# 20                      Guinea Ecuatorial Airlines          1996
# 21                         National Port Authority          1921
# 22                                  Air Madagascar          1962
# 23                      Beira Railroad Corporation          1892
# 24                             Dakar–Niger Railway          1924
# 25                                  Air Seychelles          1977
# 26                                      Swazi Rail          1963
# 27             Azerbaijan Caspian Shipping Company          1858
# 28                                     Tashi Group          1959
# 29                       Myanmar National Airlines          1948
# ..                                             ...           ...
# 133                        Casa da Moeda do Brasil          1694
# 134                     Casa de Moneda de Colombia          1621
# 135                                           BMMI          1883
# 136                        Hua Ho Department Store          1947
# 137                               M.H. Alshaya Co.          1890
# 138                           Hudson's Bay Company          1670
# 139             Ma Yu Ching's Bucket Chicken House          1153
# 140                                 Café Abu Salem          1914
# 141                                        Bakdash          1885
# 142                    St. Peter Stifts Kulinarium           803
# 143                                     Sean's Bar           900
# 144                                 Cafe Brasilero          1877
# 145                                         Pindad          1808
# 146                                     Arsenal AD          1878
# 147                                          Famae          1811
# 148                                     Kongō Gumi           578
# 149                               House of Alireza          1845
# 150                                 House of Habib          1841
# 151         Salam International Investment Limited          1952
# 152                                  B.Grimm Group          1878
# 153                     Petrodvorets Watch Factory          1721
# 154                                        Fiskars          1649
# 155                       Tutunski kombinat Prilep          1873
# 156                                 KT Corporation          1885
# 157                                     ALBtelecom          1912
# 158                                      Raeapteek          1422
# 159                                Gostilna Gastuž          1467
# 160                                Gasthof Sternen          1230
# 161                             Çemberlitaş Hamamı          1584
# 162                                      Rose Hall          1770
#
#     category_code country_code                    category  \
# 0           CAT11          DZA            Food & Beverages
# 1           CAT11          BGD            Food & Beverages
# 2           CAT11          LKA            Food & Beverages
# 3           CAT11          GTM            Food & Beverages
# 4           CAT11          GUY            Food & Beverages
# 5           CAT11          VEN            Food & Beverages
# 6           CAT10          BEN                      Energy
# 7           CAT10          IRQ                      Energy
# 8           CAT10          LAO                      Energy
# 9           CAT10          OMN                      Energy
# 10           CAT1          BWA                 Agriculture
# 11           CAT1          CMR                 Agriculture
# 12           CAT1          TCD                 Agriculture
# 13           CAT1          AFG                 Agriculture
# 14           CAT1          ESP                 Agriculture
# 15           CAT1          USA                 Agriculture
# 16           CAT2          BFA        Aviation & Transport
# 17           CAT2          COD        Aviation & Transport
# 18           CAT2          DJI        Aviation & Transport
# 19           CAT2          EGY        Aviation & Transport
# 20           CAT2          GNQ        Aviation & Transport
# 21           CAT2          LBR        Aviation & Transport
# 22           CAT2          MDG        Aviation & Transport
# 23           CAT2          MOZ        Aviation & Transport
# 24           CAT2          SEN        Aviation & Transport
# 25           CAT2          SYC        Aviation & Transport
# 26           CAT2          SWZ        Aviation & Transport
# 27           CAT2          AZE        Aviation & Transport
# 28           CAT2          BTN        Aviation & Transport
# 29           CAT2          MMR        Aviation & Transport
# ..            ...          ...                         ...
# 133         CAT12          BRA  Manufacturing & Production
# 134         CAT12          COL  Manufacturing & Production
# 135         CAT17          BHR                      Retail
# 136         CAT17          BRN                      Retail
# 137         CAT17          KWT                      Retail
# 138         CAT17          CAN                      Retail
# 139          CAT4          CHN   Cafés, Restaurants & Bars
# 140          CAT4          ISR   Cafés, Restaurants & Bars
# 141          CAT4          SYR   Cafés, Restaurants & Bars
# 142          CAT4          AUT   Cafés, Restaurants & Bars
# 143          CAT4          IRL   Cafés, Restaurants & Bars
# 144          CAT4          URY   Cafés, Restaurants & Bars
# 145          CAT8          IDN                     Defense
# 146          CAT8          BGR                     Defense
# 147          CAT8          CHL                     Defense
# 148          CAT6          JPN                Construction
# 149          CAT6          SAU                Construction
# 150          CAT5          PAK                Conglomerate
# 151          CAT5          QAT                Conglomerate
# 152          CAT5          THA                Conglomerate
# 153          CAT7          RUS              Consumer Goods
# 154          CAT7          FIN              Consumer Goods
# 155          CAT7          MKD              Consumer Goods
# 156         CAT18          KOR          Telecommunications
# 157         CAT18          ALB          Telecommunications
# 158         CAT14          EST                     Medical
# 159         CAT19          SVN            Tourism & Hotels
# 160         CAT19          CHE            Tourism & Hotels
# 161         CAT19          TUR            Tourism & Hotels
# 162         CAT19          JAM            Tourism & Hotels
#
#                                    country      continent
# 0                                  Algeria         Africa
# 1                               Bangladesh           Asia
# 2                                Sri Lanka           Asia
# 3                                Guatemala  North America
# 4                                   Guyana  South America
# 5        Venezuela, Bolivarian Republic of  South America
# 6                                    Benin         Africa
# 7                                     Iraq           Asia
# 8         Lao People's Democratic Republic           Asia
# 9                                     Oman           Asia
# 10                                Botswana         Africa
# 11                                Cameroon         Africa
# 12                                    Chad         Africa
# 13                             Afghanistan           Asia
# 14                                   Spain         Europe
# 15                           United States  North America
# 16                            Burkina Faso         Africa
# 17   Congo, The Democratic Republic of the         Africa
# 18                                Djibouti         Africa
# 19                                   Egypt         Africa
# 20                       Equatorial Guinea         Africa
# 21                                 Liberia         Africa
# 22                              Madagascar         Africa
# 23                              Mozambique         Africa
# 24                                 Senegal         Africa
# 25                              Seychelles           Asia
# 26                                Eswatini         Africa
# 27                              Azerbaijan           Asia
# 28                                  Bhutan           Asia
# 29                                 Myanmar           Asia
# ..                                     ...            ...
# 133                                 Brazil  South America
# 134                               Colombia  South America
# 135                                Bahrain           Asia
# 136                      Brunei Darussalam           Asia
# 137                                 Kuwait           Asia
# 138                                 Canada  North America
# 139                                  China           Asia
# 140                                 Israel           Asia
# 141                   Syrian Arab Republic           Asia
# 142                                Austria         Europe
# 143                                Ireland         Europe
# 144                                Uruguay  South America
# 145                              Indonesia           Asia
# 146                               Bulgaria         Europe
# 147                                  Chile  South America
# 148                                  Japan           Asia
# 149                           Saudi Arabia           Asia
# 150                               Pakistan           Asia
# 151                                  Qatar           Asia
# 152                               Thailand           Asia
# 153                     Russian Federation         Europe
# 154                                Finland         Europe
# 155                        North Macedonia         Europe
# 156                     Korea, Republic of           Asia
# 157                                Albania         Europe
# 158                                Estonia         Europe
# 159                               Slovenia         Europe
# 160                            Switzerland         Europe
# 161                                 Turkey           Asia
# 162                                Jamaica  North America
#
# [163 rows x 7 columns]

# %%
# Sort businesses_categories_countries from oldest to most recent
businesses_categories_countries = businesses_categories_countries.sort_values('year_founded')
businesses_categories_countries
# Out:
#                                            business  year_founded  \
# 148                                      Kongō Gumi           578
# 142                     St. Peter Stifts Kulinarium           803
# 44                            Staffelter Hof Winery           862
# 127                               Monnaie de Paris            864
# 126                                  The Royal Mint           886
# 143                                      Sean's Bar           900
# 128                          Marinelli Bell Foundry          1040
# 41                                 Affligem Brewery          1074
# 125                                     Munke Mølle          1135
# 139              Ma Yu Ching's Bucket Chicken House          1153
# 14                                Casa de Ganaderos          1218
# 160                                 Gasthof Sternen          1230
# 112                               Bochnia Salt Mine          1248
# 131                            Drohobych salt plant          1250
# 129                                   Kremnica Mint          1328
# 49                                The Brand Brewery          1340
# 130                                 Skyllbergs bruk          1346
# 43                                  Pivovar Broumov          1348
# 158                                       Raeapteek          1422
# 159                                 Gostilna Gastuž          1467
# 48                                           Mousel          1511
# 71                      CTT-Correios de Portugal SA          1520
# 132                     La Casa de Moneda de México          1534
# 107                         Casa Nacional de Moneda          1565
# 161                              Çemberlitaş Hamamı          1584
# 46                                        Cēsu Alus          1590
# 98                                     Piraeus Bank          1606
# 134                      Casa de Moneda de Colombia          1621
# 15                               Shirley Plantation          1638
# 70                                     Posten Norge          1647
# ..                                              ...           ...
# 136                         Hua Ho Department Store          1947
# 29                        Myanmar National Airlines          1948
# 151          Salam International Investment Limited          1952
# 90                        National Bank of Cambodia          1954
# 35                                          Brarudi          1955
# 114     Office de Radiodiffusion-Télévision du Mali          1957
# 8                               Electricite du Laos          1959
# 28                                      Tashi Group          1959
# 115         Office of Radio and Television of Niger          1960
# 32                                  Yemenia Airways          1962
# 110                                    Halco Mining          1962
# 22                                   Air Madagascar          1962
# 26                                       Swazi Rail          1963
# 113                 Malawi Broadcasting Corporation          1964
# 10                         Botswana Meat Commission          1965
# 16                                      Air Burkina          1967
# 6                    Communauté Électrique du Bénin          1968
# 77                                   BGFIBank Group          1971
# 12                                       Cotontchad          1971
# 59                         Correios da Guiné-Bissau          1973
# 81                       Central Bank of Mauritania          1973
# 84            Central Bank of São Tomé and Príncipe          1975
# 75   Development Bank of the Central African States          1975
# 25                                   Air Seychelles          1977
# 79                          Central Bank of Lesotho          1978
# 74                      Central Bank of the Comoros          1981
# 109                          European Trust Company          1991
# 86                                       Ivory Bank          1994
# 20                       Guinea Ecuatorial Airlines          1996
# 118                            Meridian Corporation          1999
#
#     category_code country_code                           category  \
# 148          CAT6          JPN                       Construction
# 142          CAT4          AUT          Cafés, Restaurants & Bars
# 44           CAT9          DEU  Distillers, Vintners, & Breweries
# 127         CAT12          FRA         Manufacturing & Production
# 126         CAT12          GBR         Manufacturing & Production
# 143          CAT4          IRL          Cafés, Restaurants & Bars
# 128         CAT12          ITA         Manufacturing & Production
# 41           CAT9          BEL  Distillers, Vintners, & Breweries
# 125         CAT12          DNK         Manufacturing & Production
# 139          CAT4          CHN          Cafés, Restaurants & Bars
# 14           CAT1          ESP                        Agriculture
# 160         CAT19          CHE                   Tourism & Hotels
# 112         CAT15          POL                             Mining
# 131         CAT12          UKR         Manufacturing & Production
# 129         CAT12          SVK         Manufacturing & Production
# 49           CAT9          NLD  Distillers, Vintners, & Breweries
# 130         CAT12          SWE         Manufacturing & Production
# 43           CAT9          CZE  Distillers, Vintners, & Breweries
# 158         CAT14          EST                            Medical
# 159         CAT19          SVN                   Tourism & Hotels
# 48           CAT9          LUX  Distillers, Vintners, & Breweries
# 71          CAT16          PRT                     Postal Service
# 132         CAT12          MEX         Manufacturing & Production
# 107          CAT3          PER                  Banking & Finance
# 161         CAT19          TUR                   Tourism & Hotels
# 46           CAT9          LVA  Distillers, Vintners, & Breweries
# 98           CAT3          GRC                  Banking & Finance
# 134         CAT12          COL         Manufacturing & Production
# 15           CAT1          USA                        Agriculture
# 70          CAT16          NOR                     Postal Service
# ..            ...          ...                                ...
# 136         CAT17          BRN                             Retail
# 29           CAT2          MMR               Aviation & Transport
# 151          CAT5          QAT                       Conglomerate
# 90           CAT3          KHM                  Banking & Finance
# 35           CAT9          BDI  Distillers, Vintners, & Breweries
# 114         CAT13          MLI                              Media
# 8           CAT10          LAO                             Energy
# 28           CAT2          BTN               Aviation & Transport
# 115         CAT13          NER                              Media
# 32           CAT2          YEM               Aviation & Transport
# 110         CAT15          GIN                             Mining
# 22           CAT2          MDG               Aviation & Transport
# 26           CAT2          SWZ               Aviation & Transport
# 113         CAT13          MWI                              Media
# 10           CAT1          BWA                        Agriculture
# 16           CAT2          BFA               Aviation & Transport
# 6           CAT10          BEN                             Energy
# 77           CAT3          GAB                  Banking & Finance
# 12           CAT1          TCD                        Agriculture
# 59          CAT16          GNB                     Postal Service
# 81           CAT3          MRT                  Banking & Finance
# 84           CAT3          STP                  Banking & Finance
# 75           CAT3          COG                  Banking & Finance
# 25           CAT2          SYC               Aviation & Transport
# 79           CAT3          LSO                  Banking & Finance
# 74           CAT3          COM                  Banking & Finance
# 109          CAT3          VUT                  Banking & Finance
# 86           CAT3          SSD                  Banking & Finance
# 20           CAT2          GNQ               Aviation & Transport
# 118         CAT13           XK                              Media
#
#                               country      continent
# 148                             Japan           Asia
# 142                           Austria         Europe
# 44                            Germany         Europe
# 127                            France         Europe
# 126                    United Kingdom         Europe
# 143                           Ireland         Europe
# 128                             Italy         Europe
# 41                            Belgium         Europe
# 125                           Denmark         Europe
# 139                             China           Asia
# 14                              Spain         Europe
# 160                       Switzerland         Europe
# 112                            Poland         Europe
# 131                           Ukraine         Europe
# 129                          Slovakia         Europe
# 49                        Netherlands         Europe
# 130                            Sweden         Europe
# 43                            Czechia         Europe
# 158                           Estonia         Europe
# 159                          Slovenia         Europe
# 48                         Luxembourg         Europe
# 71                           Portugal         Europe
# 132                            Mexico  North America
# 107                              Peru  South America
# 161                            Turkey           Asia
# 46                             Latvia         Europe
# 98                             Greece         Europe
# 134                          Colombia  South America
# 15                      United States  North America
# 70                             Norway         Europe
# ..                                ...            ...
# 136                 Brunei Darussalam           Asia
# 29                            Myanmar           Asia
# 151                             Qatar           Asia
# 90                           Cambodia           Asia
# 35                            Burundi         Africa
# 114                              Mali         Africa
# 8    Lao People's Democratic Republic           Asia
# 28                             Bhutan           Asia
# 115                             Niger         Africa
# 32                              Yemen           Asia
# 110                            Guinea         Africa
# 22                         Madagascar         Africa
# 26                           Eswatini         Africa
# 113                            Malawi         Africa
# 10                           Botswana         Africa
# 16                       Burkina Faso         Africa
# 6                               Benin         Africa
# 77                              Gabon         Africa
# 12                               Chad         Africa
# 59                      Guinea-Bissau         Africa
# 81                         Mauritania         Africa
# 84              Sao Tome and Principe         Africa
# 75                              Congo         Africa
# 25                         Seychelles           Asia
# 79                            Lesotho         Africa
# 74                            Comoros         Africa
# 109                           Vanuatu        Oceania
# 86                        South Sudan         Africa
# 20                  Equatorial Guinea         Africa
# 118                            Kosovo         Europe
#
# [163 rows x 7 columns]

# %%
# Create the oldest by continent and category DataFrame
oldest_by_continent_category =  businesses_categories_countries.groupby(["continent", "category"]).agg({"year_founded":"min"})
oldest_by_continent_category
# Out:
#                                                  year_founded
# continent     category
# Africa        Agriculture                                1947
#               Aviation & Transport                       1854
#               Banking & Finance                          1892
#               Distillers, Vintners, & Breweries          1933
#               Energy                                     1968
#               Food & Beverages                           1878
#               Manufacturing & Production                 1820
#               Media                                      1943
#               Mining                                     1962
#               Postal Service                             1772
# Asia          Agriculture                                1930
#               Aviation & Transport                       1858
#               Banking & Finance                          1830
#               Cafés, Restaurants & Bars                  1153
#               Conglomerate                               1841
#               Construction                                578
#               Defense                                    1808
#               Distillers, Vintners, & Breweries          1853
#               Energy                                     1928
#               Food & Beverages                           1820
#               Manufacturing & Production                 1736
#               Media                                      1931
#               Mining                                     1913
#               Postal Service                             1800
#               Retail                                     1883
#               Telecommunications                         1885
#               Tourism & Hotels                           1584
# Europe        Agriculture                                1218
#               Banking & Finance                          1606
#               Cafés, Restaurants & Bars                   803
#               Consumer Goods                             1649
#               Defense                                    1878
#               Distillers, Vintners, & Breweries           862
#               Manufacturing & Production                  864
#               Media                                      1999
#               Medical                                    1422
#               Mining                                     1248
#               Postal Service                             1520
#               Telecommunications                         1912
#               Tourism & Hotels                           1230
# North America Agriculture                                1638
#               Aviation & Transport                       1870
#               Banking & Finance                          1891
#               Distillers, Vintners, & Breweries          1703
#               Food & Beverages                           1920
#               Manufacturing & Production                 1534
#               Media                                      1909
#               Retail                                     1670
#               Tourism & Hotels                           1770
# Oceania       Banking & Finance                          1861
#               Postal Service                             1809
# South America Banking & Finance                          1565
#               Cafés, Restaurants & Bars                  1877
#               Defense                                    1811
#               Food & Beverages                           1660
#               Manufacturing & Production                 1621
